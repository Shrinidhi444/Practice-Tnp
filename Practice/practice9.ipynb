# %% [markdown]
# # MACHINE LEARNING STEPS

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
#numpy
"""
2 - scalar
[1,2,3] - vector
[[1,2],[3,4]] - matrix
"""
# pandas
"""
1d - series - homogenous array,size-immutable
2d - dataframe - hetrogenously typed columns,size-mutable
"""
# Out:
# '\n1d - series - homogenous array,size-immutable\n2d - dataframe - hetrogenously typed columns,size-mutable\n'

# %% [markdown]
# # SYNTAX OF SERIES

# %%
#PANDAS.SERIES(DATA,INDEX,DTYPE)

# %%
series = pd.Series([1,2,3,4,5])
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series1 = pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
print(series1)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
for i in series1:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
series2 = pd.Series(np.random.randn(5),
                    index=['a','b','c','d','e'])

print(series2)
# Out:
# a   -1.127436
# b   -1.763089
# c   -0.764077
# d   -0.589083
# e    1.722783
# dtype: float64

# %%
series2 = pd.Series(np.random.random(5),
                    index=['a','b','c','d','e'])

print(series2)
# Out:
# a    0.869308
# b    0.766963
# c    0.048165
# d    0.953916
# e    0.628693
# dtype: float64

# %% [markdown]
# # creating series using dictionary

# %%
dictionary = {'a':1,'b':2, 'c':3}
d1 = pd.Series(dictionary)
d1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# [] - series
#[[]] - dataframe

# %%
# d1[[1,2]] #based on column name
d1.iloc[[1,2]] # index based
# Out:
# b    2
# c    3
# dtype: int64

# %%
series1 + series2 #addition of two series
# Out:
# a    1.869308
# b    2.766963
# c    3.048165
# d    4.953916
# e    5.628693
# dtype: float64

# %%
series + series1 # error not a number
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# dtype: float64

# %% [markdown]
# # Empty DataFrame

# %%
df = pd.DataFrame() # creating empty matrix or dataframe
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame(columns = ['c1','c2','c3']) # adding column 
print(df)
# Out:
# Empty DataFrame
# Columns: [c1, c2, c3]
# Index: []

# %%
df=pd.DataFrame(columns = ['c1','c2','c3','c4'], # creates the 5 rows doesn't throw the error 
                index = range(1,6))  # rows
print(df)
# Out:
#     c1   c2   c3   c4
# 1  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN

# %%
dictionary = {'a':1,'b':2, 'c':3}  # column : rows
pd.DataFrame([dictionary])
# Out:
#    a  b  c
# 0  1  2  3

# %% [markdown]
# # Attributes

# %%
df.index
# Out:
# RangeIndex(start=1, stop=6, step=1)

# %%
df.columns
# Out:
# Index(['c1', 'c2', 'c3', 'c4'], dtype='object')

# %% [markdown]
# # create a data frame using list

# %%
mylist = [
    ['apple','red'],
    ['banana','yellow'],
    ['orange','orsnge']
]

mydata = pd.DataFrame(mylist)
mydata
# Out:
#         0       1
# 0   apple     red
# 1  banana  yellow
# 2  orange  orsnge

# %%
mydata = pd.DataFrame(mylist, columns = ('fruits','colour'))
mydata
# Out:
#    fruits  colour
# 0   apple     red
# 1  banana  yellow
# 2  orange  orsnge

# %% [markdown]
# # Dataframes using numpy array

# %%
mylist1 = np.array([
    [0,1],
    [2,3],
    [4,5]
])

mydf = pd.DataFrame(mylist1,columns = ['Even','Odd'])
mydf
# Out:
#    Even  Odd
# 0     0    1
# 1     2    3
# 2     4    5

# %% [markdown]
# # load CSV data from pandas

# %%
df = pd.read_csv('./cereals.csv') # path of csv file -- taking directly from my files use //
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.set_index('name') # it will return a new dataframe
#df.set_index('name', inplace = True) # it will modify th original value
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %% [markdown]
# # Examining the DataFrme

# %%
df.head()
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
df.tail()
# Out:
#                       name  calories  protein  vitamins     rating
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
df.describe()
# Out:
#          calories    protein   vitamins     rating
# count   10.000000  10.000000  10.000000  10.000000
# mean    95.000000   2.900000  22.500000  49.205817
# std     25.495098   0.875595   7.905694  20.315297
# min     50.000000   2.000000   0.000000  29.509541
# 25%     75.000000   2.000000  25.000000  34.083970
# 50%    100.000000   3.000000  25.000000  43.079408
# 75%    110.000000   3.750000  25.000000  57.897582
# max    130.000000   4.000000  25.000000  93.704912

# %%
# Slicig rows using bracket operators

# %%
df[1:4]
# Out:
#                         name  calories  protein  vitamins     rating
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df['calories':'rating'] # cannot do slicing
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[161], line 1
# ----> 1 df['calories':'rating']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4085, in DataFrame.__getitem__(self, key)
#    4083 # Do we have a slicer (on rows)?
#    4084 if isinstance(key, slice):
# -> 4085     return self._getitem_slice(key)
#    4087 # Do we have a (boolean) DataFrame?
#    4088 if isinstance(key, DataFrame):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4349, in NDFrame._getitem_slice(self, key)
#    4344 """
#    4345 __getitem__ for the case where the key is a slice object.
#    4346 """
#    4347 # _convert_slice_indexer to determine if this slice is positional
#    4348 #  or label based, and if the latter, convert to positional
# -> 4349 slobj = self.index._convert_slice_indexer(key, kind="getitem")
#    4350 if isinstance(slobj, np.ndarray):
# ...

# %%
df['calories','rating'] # cant fectch multiple columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('calories', 'rating')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 df['calories','rating']
#
# ...

# %%
df[['calories','rating']] # can fetch the columns using two square brackets
# Out:
#    calories     rating
# 0        70  68.402973
# 1       120  33.983679
# 2        70  59.425505
# 3        50  93.704912
# 4       110  34.384843
# 5       110  29.509541
# 6       110  33.174094
# 7       130  37.038562
# 8        90  49.120253
# 9        90  53.313813

# %% [markdown]
# # Boolean filter

# %%
df1 =  df[0:5]
boolean_list =[True,False,True,True,False]
df1[boolean_list]
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df['calories'] > 70 #returns boolean values
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: calories, dtype: bool

# %%
condition = df['calories'] > 70
df[condition]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %% [markdown]
# # Filtering rows using &(and) and |(or)

# %%
df[(df['calories'] > 70) & (df['protein'] < 3)]
# Out:
#                       name  calories  protein  vitamins     rating
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 8                Bran Chex        90        2        25  49.120253

# %% [markdown]
# # Filtering using loc()

# %%
df.loc[2,'protein'] # retuns in series format
# Out:
# 4

# %%
df.loc[0:4,['protein','name']]
# Out:
#    protein                       name
# 0        4                  100% Bran
# 1        3          100% Natural Bran
# 2        4                   All-Bran
# 3        4  All-Bran with Extra Fiber
# 4        2             Almond Delight

# %%
df.loc[2:4,['protein']]
# more than one column will automatically considered as dataframe so no need to specify in[]
df.loc[0:4,'name':'protein']
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4                       shri       110        1

# %% [markdown]
# # indexing and slicing

# %%
df.iloc[[0,2,4],0:3]
# Out:
#              name  calories  protein
# 0       100% Bran        70        4
# 2        All-Bran        70        4
# 4  Almond Delight       110        2

# %%
df.iloc[1,2]
# Out:
# 3

# %%
# Adding and Deleting rows from dataframe

# %%
df1.loc[4] = ['shri',110,1,40,27.35] # it will update in the original dataframe
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                       shri       110        1        40  27.350000

# %%
df # updated in main dataframe

# changes made in df1 will affect the df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                       shri       110        1        40  27.350000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.iloc[[1,2]]
# Out:
#                 name  calories  protein  vitamins     rating
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505

# %%
df.iloc[0:5,0:3]   #first represent row ,second represnt column
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4                       shri       110        1

# %%
df.iloc[[0,2,4],0:3]
# Out:
#         name  calories  protein
# 0  100% Bran        70        4
# 2   All-Bran        70        4
# 4       shri       110        1

# %%
df1 = df.iloc[0:5,].copy() # it will not change the original dataframe
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                       shri       110        1        40  27.350000

# %%
df1.drop(4, axis=0, inplace=True) # deletes the sepecific row
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505

# %%
df1.loc[4] = ['shri',110,1,40,27.35] # retrieved back the original
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505
# 3               shri       110        1        40  27.350000
# 4               shri       110        1        40  27.350000

# %%
df1.drop(4, axis=0, inplace=True) # deletes the sepecific 4th row
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505
# 3               shri       110        1        40  27.350000

# %%
df1.drop("name",axis=1) # to delete the column -- 'name' donesnt make any changes in original dataframe
# Out:
#    calories  protein  vitamins     rating  new_column
# 0        70        4        25  68.402973           1
# 1       120        3         0  33.983679           2
# 2        70        4        25  59.425505           3
# 3       110        1        40  27.350000           4

# %%
df1 # doesnt changed
# Out:
#                 name  calories  protein  vitamins     rating  new_column
# 0          100% Bran        70        4        25  68.402973           1
# 1  100% Natural Bran       120        3         0  33.983679           2
# 2           All-Bran        70        4        25  59.425505           3
# 3               shri       110        1        40  27.350000           4

# %% [markdown]
# # Adds new Column

# %%
df1['new_column']=[1,2,3,4] # adds new column
df1
# Out:
#                 name  calories  protein  vitamins     rating  new_column
# 0          100% Bran        70        4        25  68.402973           1
# 1  100% Natural Bran       120        3         0  33.983679           2
# 2           All-Bran        70        4        25  59.425505           3
# 3               shri       110        1        40  27.350000           4

# %% [markdown]
# # Sorting values

# %%
asc_df = df.sort_values(by = 'calories') # Ascending order

# %%
asc_df
# Out:
#                         name  calories  protein  vitamins     rating
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 4                       shri       110        1        40  27.350000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 1          100% Natural Bran       120        3         0  33.983679
# 7                    Basic 4       130        3        25  37.038562

# %%
desc_df = df.sort_values(by = 'calories',ascending = False)

# %%
desc_df
# Out:
#                         name  calories  protein  vitamins     rating
# 7                    Basic 4       130        3        25  37.038562
# 1          100% Natural Bran       120        3         0  33.983679
# 4                       shri       110        1        40  27.350000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %% [markdown]
# # Changing the column index

# %%
df.columns = ['col1','col2','col3','col4','col5'] # change the column names

# %%
df
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                       shri   110     1    40  27.350000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %% [markdown]
# # Exporting and Saving panadas dataframe

# %%
df.to_csv('./cereals.csv') # adds its own index in the df table considering the old as the column of the old table

# %%
newdf = pd.read_csv('./cereals.csv')
newdf
# Out:
#    Unnamed: 0                       col1  col2  col3  col4       col5
# 0           0                  100% Bran    70     4    25  68.402973
# 1           1          100% Natural Bran   120     3     0  33.983679
# 2           2                   All-Bran    70     4    25  59.425505
# 3           3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4           4                       shri   110     1    40  27.350000
# 5           5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6           6                Apple Jacks   110     2    25  33.174094
# 7           7                    Basic 4   130     3    25  37.038562
# 8           8                  Bran Chex    90     2    25  49.120253
# 9           9                Bran Flakes    90     3    25  53.313813

# %%
df.to_csv('./cereals.csv', index_label = False) # doesnt add the nes index

# %%
newdf = pd.read_csv('./cereals.csv')
newdf
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                       shri   110     1    40  27.350000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %% [markdown]
# # descending desc_df('./cereals.csv')

# %% [markdown]
# # Concating

# %%
df2 = df[5:8].copy()
df2
# Out:
#                       col1  col2  col3  col4       col5
# 5  Apple Cinnamon Cheerios   110     2    25  29.509541
# 6              Apple Jacks   110     2    25  33.174094
# 7                  Basic 4   130     3    25  37.038562

# %%
df1 = df1.reset_index(drop = True)  # reset is used for row which retrieves the original names of the table
df1
# Out:
#                 name  calories  protein  vitamins     rating  new_column
# 0          100% Bran        70        4        25  68.402973           1
# 1  100% Natural Bran       120        3         0  33.983679           2
# 2           All-Bran        70        4        25  59.425505           3
# 3               shri       110        1        40  27.350000           4

# %%
df2 = df2.reset_index(drop = True)
df2
# Out:
#                       col1  col2  col3  col4       col5
# 0  Apple Cinnamon Cheerios   110     2    25  29.509541
# 1              Apple Jacks   110     2    25  33.174094
# 2                  Basic 4   130     3    25  37.038562

# %%
# to remove the new column from df1
df1.drop('new_column',axis=1,inplace=True)

# %%
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505
# 3               shri       110        1        40  27.350000

# %%
df = pd.read_csv('./cereals.csv')
df
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                       shri   110     1    40  27.350000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %%
pd.concat([df1,df2]) # arranges the indexes present in the table as it is!!
# Out:
#                 name  calories  protein  vitamins     rating  \
# 0          100% Bran      70.0      4.0      25.0  68.402973
# 1  100% Natural Bran     120.0      3.0       0.0  33.983679
# 2           All-Bran      70.0      4.0      25.0  59.425505
# 3               shri     110.0      1.0      40.0  27.350000
# 0                NaN       NaN      NaN       NaN        NaN
# 1                NaN       NaN      NaN       NaN        NaN
# 2                NaN       NaN      NaN       NaN        NaN
#
#                       col1   col2  col3  col4       col5
# 0                      NaN    NaN   NaN   NaN        NaN
# 1                      NaN    NaN   NaN   NaN        NaN
# 2                      NaN    NaN   NaN   NaN        NaN
# 3                      NaN    NaN   NaN   NaN        NaN
# 0  Apple Cinnamon Cheerios  110.0   2.0  25.0  29.509541
# 1              Apple Jacks  110.0   2.0  25.0  33.174094
# 2                  Basic 4  130.0   3.0  25.0  37.038562

# %%
pd.concat([df1,df2],ignore_index=True) # reset the index numbers arranges index sequentially
# Out:
#                 name  calories  protein  vitamins     rating  \
# 0          100% Bran      70.0      4.0      25.0  68.402973
# 1  100% Natural Bran     120.0      3.0       0.0  33.983679
# 2           All-Bran      70.0      4.0      25.0  59.425505
# 3               shri     110.0      1.0      40.0  27.350000
# 4                NaN       NaN      NaN       NaN        NaN
# 5                NaN       NaN      NaN       NaN        NaN
# 6                NaN       NaN      NaN       NaN        NaN
#
#                       col1   col2  col3  col4       col5
# 0                      NaN    NaN   NaN   NaN        NaN
# 1                      NaN    NaN   NaN   NaN        NaN
# 2                      NaN    NaN   NaN   NaN        NaN
# 3                      NaN    NaN   NaN   NaN        NaN
# 4  Apple Cinnamon Cheerios  110.0   2.0  25.0  29.509541
# 5              Apple Jacks  110.0   2.0  25.0  33.174094
# 6                  Basic 4  130.0   3.0  25.0  37.038562

# %%
# Groupby

# %%
data = {'Gender':['female','male','female','male'],
        'score':[56,67,78,89]}

#new_df = pd.DataFrame.from_dict(data)
new_df = pd.DataFrame(data)
new_df
# Out:
#    Gender  score
# 0  female     56
# 1    male     67
# 2  female     78
# 3    male     89

# %%
group = new_df.groupby(new_df['Gender']).mean()
group
# Out:
#         score
# Gender
# female   67.0
# male     78.0
